# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from math import sin, exp
from scipy import optimize

# %%
def f(x):
  return sin(x / 5.0) * exp(x / 10.0) + 5.0 * exp(-x / 2.0)  #от 1 до 30 включительно

# %%
def h(x):
  return int(f(x))

# %%
f_v = np.vectorize(f)
x_1 = np.arange(1, 30, 1)
y_1 = f_v(x_1)
plt.plot(x_1, y_1)

# %%
x0 = np.array(30)
optimize.minimize(h, x0, method='BFGS', bounds=(1, 30))
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/_minimize.py:522: RuntimeWarning: Method BFGS cannot handle constraints nor bounds.
#   RuntimeWarning)
#       fun: -5
#  hess_inv: array([[1]])
#       jac: array([0.])
#   message: 'Optimization terminated successfully.'
#      nfev: 3
#       nit: 0
#      njev: 1
#    status: 0
#   success: True
#         x: array([30.])

# %%
optimize.differential_evolution(h, [(1, 30)])
# Out:
#      fun: -11.0
#  message: 'Optimization terminated successfully.'
#     nfev: 92
#      nit: 5
#  success: True
#        x: array([26.52292436])
